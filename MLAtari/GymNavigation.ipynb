# %% [markdown]
# ## Navigating OpenAI Gym

# %%
import gym

# %%
env = gym.make('MountainCar-v0')

# %%
state_space = env.observation_space
state_space
# Out:
# Box(2,)

# %%
action_space = env.action_space.n
action_space
# Out:
# 3

# %%
# Play 3 Games
for episode in range(3):
    env.reset()
    done = False
    while not done:
        # this line renders the game graphically so we can watch it play
        env.render()
        # the sample environment method grabs a random action; in this case, just
        # an integer between 0-5
        action = env.action_space.sample()

        observation, reward, done, info = env.step(action)
    env.close()

# %%
from gym.utils import play
play.play(env)
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-67b751c33356> in <module>
#       2 # this might crash a lil bit, but it's ok
#       3 from gym.utils import play
# ----> 4 play.play(env)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gym/utils/play.py in play(env, transpose, fps, zoom, callback, keys_to_action)
#      87         else:
#      88             assert False, env.spec.id + " does not have explicit key to action mapping, " + \
# ---> 89                           "please specify one manually"
#      90     relevant_keys = set(sum(map(list, keys_to_action.keys()),[]))
#      91
#
# AssertionError: CartPole-v0 does not have explicit key to action mapping, please specify one manually
